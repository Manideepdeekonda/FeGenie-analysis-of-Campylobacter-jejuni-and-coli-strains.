# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load data
data = pd.read_csv('FeGenie_output/FeGenie-heatmap-data.csv')

# Display first few rows of the DataFrame
data.head()
# Out:
#                                        X  1220.fas  16129.fas  16184.fas  \
# 0         iron_aquisition-iron_transport         5          2          4
# 1         iron_aquisition-heme_transport         0          0          1
# 2         iron_aquisition-heme_oxygenase         0          0          0
# 3  iron_aquisition-siderophore_synthesis         3          3          0
# 4  iron_aquisition-siderophore_transport        12         12         14
#
#    16192.fas  16274.fas  16367.fas  18294.fas  21313.fas  22259.fas  ...  \
# 0          3          0          2          2          4          4  ...
# 1          1          0          1          1          1          1  ...
# 2          0          0          0          0          0          0  ...
# 3          0          3          3          0          3          0  ...
# 4         14         12         14         16         16         16  ...
#
#    70690.fas  76512.fas  76662.fas  77284.fas  78191.fas  78255.fas  \
# ...

# %%
data.set_index('X', inplace=True)

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(data, annot=True, cmap='coolwarm', linewidths=.5)

# Customizing the plot
plt.title("FeGenie Heatmap", fontsize=20)
plt.xlabel("Gene sequences", fontsize=15)
plt.ylabel("Iron acquisition/regulation", fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.savefig('heatmap.png', dpi=300, bbox_inches='tight')
# Display the heatmap
plt.show()
